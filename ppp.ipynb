# %%
num = int(input("정수를 입력하세요: "))

if num % 2 == 0:
    print("짝수입니다.")
else:
    print("홀수입니다.")

# %%
score = int(input("점수를 입력하세요: "))

if score >= 90:
    print("A")
elif score >= 80:
    print("B")
elif score >= 70:
    print("C")
elif score >= 60:
    print("D")
else:
    print("F")

# %%
score = int(input())

if score >= 90:
    print('A')
    if score >= 95:
        print('good!!!')
elif score >= 80:
    print('B')
elif score >= 70:
    print('C')
else:
    print('F')

# %%
for i in range(5):
    print(i)

# %%
numbers = range(1, 51)

for number in numbers:
    if number % 5 == 0:
        print(number)

# %%
locations = ['서울', '대전', '부산']
for (index, location) in enumerate(locations):
    print(index)
    print(location)

# %%
num = int(input('정수입력'))

if num > 0:
    print('양수.')
else:
    print('음수.')

# %%
num = int(input('정수 입력:'))

if num % 2 == 0:
    print('짝수')
else:
    print('홀수')

# %%
num1 = int(input('첫번째 정수'))
num2 = int(input('두번째 정수'))

if num1 > num2:
    print(num1)
else:
    print(num2)

# %%
year = int(input('연도 입력'))

if (year % 4 == 0 and year % 100 !=0) or (year % 400 == 0):
    print('윤년')
else:
    print('평년')

# %%
num = int(input('정수입력'))

if 1 <= num <= 100:
    print('1과 100사이')
else:
    print('1과 100사이 아님')

# %%
for i in range(1, 11):
    print(i, end=' ')

# %%
for i in range(1, 21):
    if i % 2 ==0:
        print(i, end=' ')

# %%
total = 0
for i in range(1, 101):
    total += i
print(total)

# %%
num = int(input('구구단'))

for i in range(1, 10):
    print(f'{num} x {i} = {num * i}')

# %%
height2 = 50
width2 = 50

area2 = height2 * width2
perimeter2 = (height2 + width2) * 2

# %%
height = 50
width = 20

area = height * width
perimeter = (height + width) * 2

print(f'사각형의 면적은 {area}이고 둘레는 {perimeter}입니다.')

# %%
def rectangle(height, width):
    area = height * width
    perimeter = (height + width) * 2

    print(f' 사각형의 면적은 {area}입니다. 둘레는 {perimeter}입니다.')

# %%
rectangle(50, 30)

# %%
max(100, 2)

# %%
def my_max(num1, num2):
    if num1 > num2:
        print(num1)
    elif num1 < num2:
        print(num2)
    else:
        print('같다')

# %%
my_max(5, 5)
my_max(5, 1)
my_max(1, 5)

# %%
result = my_max(1, 2)
print(result)

# %%
def my_max2(num1, num2):
    if num1 > num2:
        return num1
    else:
        return num2

# %%
result = my_max2(1, 2)
print(result)

# %%
def my_for(x):
    for i in range(x):
        print(i)
        if i == 3:
            return i

my_for(5)

# %%
def my_def(x):
    return (x * 2, x)

my_def(10)

# %%
def my_list_max(list1, list2):
    #list1 = [1, 2, 3]
    #list2 = [2, 3, 4]
    sum_of_list1 = list1[0] + list1[1] + list[2]
    sum_of_list2 = list2[0] + list2[1] + list[2]

    if sum_of_list1 > sum_oflist2:
        return list1
    else:
        return list2

# %%
my_list_max([55, 44, 22], [2, 3, 4])
# => [2, 3, 4]
# Out:
# [55, 44, 22]

# %%
# version3
def my_list_max(list1, list2):
    sum_of_list1 = sum(list1)
    sum_of_list2 = sum(list2)

    if sum_of_list1 > sum_of_list2:
        return list1
    else:
        return list2

# %%
def cylinder(r, h):
    return 3.14 * r ** 2 * h

# %%
cylinder(3, 10)
# Out:
# 282.6

# %%
cylinder(10, 3)
# Out:
# 942.0

# %%
def greeting(name='익명'):
    return f'{name}님 반갑습니다.'

# %%
greeting('')
# Out:
# '님 반갑습니다.'

# %%
a = 'hello my name is hong'

# %%
print(a)
# Out:
# hello my name is hong

# %%
a = a.capitalize()

# %%
print(a)
# Out:
# Hello my name is hong

# %%
a.title()
# Out:
# 'Hello My Name Is Hong'

# %%
a.lower()
# Out:
# 'hello my name is hong'

# %%
my_list = ['my', 'name', 'is']
'!'.join(my_list)
# Out:
# 'my!name!is'

# %%
'?'.join('배고프다')
# Out:
# '배?고?프?다'

# %%
a = '\t           hello         \n'
a.strip()
# Out:
# 'hello'

# %%
a = '!!!!hello!!!!!!'
a.strip('!')
# Out:
# 'hello'

# %%
a = '--------------hello-----------'
a.lstrip('-')
# Out:
# 'hello-----------'

# %%
a.rstrip('-')
# Out:
# '--------------hello'

# %%
a = 'woooooooooooooooow'
a.replace('o', '!', 3)
# Out:
# 'w!!!ooooooooooooow'

# %%
a = 'apple'
a. find('a')
# Out:
# 0

# %%
a = 'apple'
a. index('e')
# Out:
# 4

# %%
a = 'my name is hong'
a.split()
# Out:
# ['my', 'name', 'is', 'hong']

# %%
a = 'woooooooooooooooooow'
a.count('o')
# Out:
# 18

# %%
numbers = [2, 6, 1, 4, 8, 3, 2, 8]

# %%
numbers.append(10)
print(numbers)
# Out:
# [2, 6, 1, 4, 8, 3, 2, 8, 10]

# %%
a = [99, 100]

# %%
numbers.extend(a)
print(numbers)
# Out:
# [2, 6, 1, 4, 8, 3, 2, 8, 10, 99, 100]

# %%
numbers.insert(3, 5)
print(numbers)
# Out:
# [2, 6, 1, 5, 4, 8, 3, 2, 8, 10, 99, 100]

# %%
numbers.remove(8)
print(numbers)
# Out:
# [2, 6, 1, 5, 4, 3, 2, 10, 99, 100]

# %%
numbers.pop()
print(numbers)
# Out:
# [2, 6, 1, 5, 4, 3, 2, 10, 99]

# %%
numbers.pop(0)
print(numbers)
# Out:
# [6, 1, 5, 4, 3, 2, 10, 99]

# %%
numbers.sort(reverse=True)
print(numbers)
# Out:
# [99, 10, 6, 5, 4, 3, 2, 1]

# %%
a = [5, 3, 2, 7, 8, 1]
print(sorted(a))
print(a)
# Out:
# [1, 2, 3, 5, 7, 8]
# [5, 3, 2, 7, 8, 1]

# %%
my_list = ['a', '하', '나', 'b', 'z']
my_list.sort()
print(my_list)
# Out:
# ['a', 'b', 'z', '나', '하']

# %%
print(numbers)
numbers.reverse()
print(numbers)
# Out:
# [99, 10, 6, 5, 4, 3, 2, 1]
# [1, 2, 3, 4, 5, 6, 10, 99]

# %%
numbers.count(10)
# Out:
# 1

# %%
origin_list = [1, 2, 3]
copy_list = origin_list

# %%
print(origin_list)
print(copy_list)
# Out:
# [1, 2, 3]
# [1, 2, 3]

# %%
copy_list[0] = 100
print(origin_list)
print(copy_list)
# Out:
# [100, 2, 3]
# [100, 2, 3]

# %%
origin_list = [1, 2, 3]
copy_list = origin_list[:]

copy_list[0] = 100

print(origin_list)
print(copy_list)
# Out:
# [1, 2, 3]
# [100, 2, 3]

# %%
import random

my_numbers = {}

for i in range(1, 6):
    random_numbers = random.sample(range(1,46), 6)
    random_numbers.sort()
    my_numbers[i] = random_numbers
print(my_numbers)
# Out:
# {1: [2, 24, 25, 29, 32, 34], 2: [5, 12, 17, 25, 33, 37], 3: [5, 17, 19, 28, 32, 33], 4: [3, 15, 16, 17, 27, 37], 5: [2, 9, 23, 24, 29, 41]}

# %%
import requests

Lotto_URL = 'https://www.dhlottery.co.kr/common.do'
payload = {
    'method': 'getLottoNumber',
    'drwNo': 1159,
    
}

res = requests.get(Lotto_URL, params=payload)
lotto_dict = res.json()

print(lotto_dict)

lucky_numbers = []
bonus_number = lotto_dict['bnusNo']

for k, v in lotto_dict.items():
    if 'drwtNo' in k:
        lucky_numbers.append(v)

print(lucky_numbers)
# Out:
# {'totSellamnt': 124802304000, 'returnValue': 'success', 'drwNoDate': '2025-02-15', 'firstWinamnt': 1284854250, 'drwtNo6': 39, 'drwtNo4': 28, 'firstPrzwnerCo': 23, 'drwtNo5': 38, 'bnusNo': 7, 'firstAccumamnt': 29551647750, 'drwNo': 1159, 'drwtNo2': 9, 'drwtNo3': 27, 'drwtNo1': 3}
# [39, 28, 38, 9, 27, 3]

# %%
for my_number in my_numbers.values():
    my_number_set = set(my_number)
    lucky_numbers_set = set(lucky_numbers)

    match_count = len(my_number_set & lucky_numbers_set)

    if match_count == 6:
        print('1등!!!')
    elif match_count == 5 and bonus_number in my_number:
        print('2등!!!')

# %%
from datetime import datetime

# %%
datetime.now()
# Out:
# datetime.datetime(2025, 2, 19, 17, 12, 38, 949909)

# %%
datetime.today()
# Out:
# datetime.datetime(2025, 2, 19, 17, 12, 54, 702108)

# %%
import requests

# %%
r = requests.get('https://api.github.com/events')

# %%
print(r.text)
# Out:
# [{"id":"46720942477","type":"PushEvent","actor":{"id":65212910,"login":"Hall-1910","display_login":"Hall-1910","gravatar_id":"","url":"https://api.github.com/users/Hall-1910","avatar_url":"https://avatars.githubusercontent.com/u/65212910?"},"repo":{"id":222505696,"name":"brand22/d3","url":"https://api.github.com/repos/brand22/d3"},"payload":{"repository_id":222505696,"push_id":22736192120,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"372eab34c321301ae3a82d2a579d96c02ac76869","before":"dda658938d85e38d14abb417cdd7a099907c8675","commits":[{"sha":"372eab34c321301ae3a82d2a579d96c02ac76869","author":{"email":"65212910+Hall-1910@users.noreply.github.com","name":"Hall-1910"},"message":"m","distinct":true,"url":"https://api.github.com/repos/brand22/d3/commits/372eab34c321301ae3a82d2a579d96c02ac76869"}]},"public":true,"created_at":"2025-02-19T08:08:40Z"},{"id":"46720942485","type":"WatchEvent","actor":{"id":165921179,"login":"youdao2032","display_login":"youdao2032","gravatar_i
# ...

# %%
import random

# 포켓몬 클래스 정의
class Pokemon:
    def __init__(self, name, level=5):
        self.name = name            # 포켓몬 이름
        self.level = level          # 포켓몬 레벨 (기본값 5)
        self.hp = level * 10        # 체력은 레벨에 따라 결정 (예: 레벨 5면 체력 50)

    def attack(self, opponent):
        # 간단한 공격: 데미지는 레벨과 1부터 3 사이의 랜덤 숫자를 곱해 결정합니다.
        damage = self.level * random.randint(1, 3)
        print(f"{self.name}이(가) {opponent.name}에게 {damage}의 데미지를 입혔습니다!")
        opponent.hp -= damage

    def is_knocked_out(self):
        # 체력이 0 이하이면 쓰러진 것으로 간주
        return self.hp <= 0

    def status(self):
        # 현재 상태(이름과 체력)를 출력하는 메서드
        print(f"{self.name} - 체력: {self.hp}")

# 포켓몬 객체 생성 (타입 정보를 제거)
kobugi = Pokemon("꼬부기", level=5)
pairi = Pokemon("파이리", level=5)

# 배틀 시뮬레이션 시작
print("배틀 시작!")
while True:
    # 꼬부기가 파이리를 공격
    kobugi.attack(pairi)
    if pairi.is_knocked_out():
        print(f"{pairi.name}가 쓰러졌습니다! {kobugi.name} 승리!")
        break

    # 파이리가 꼬부기를 공격
    pairi.attack(kobugi)
    if kobugi.is_knocked_out():
        print(f"{kobugi.name}가 쓰러졌습니다! {pairi.name} 승리!")
        break

    # 각 포켓몬의 현재 체력을 출력
    kobugi.status()
    pairi.status()
    print("----------")
# Out:
# 배틀 시작!
# 꼬부기이(가) 파이리에게 10의 데미지를 입혔습니다!
# 파이리이(가) 꼬부기에게 10의 데미지를 입혔습니다!
# 꼬부기 - 체력: 40
# 파이리 - 체력: 40
# ----------
# 꼬부기이(가) 파이리에게 15의 데미지를 입혔습니다!
# 파이리이(가) 꼬부기에게 15의 데미지를 입혔습니다!
# 꼬부기 - 체력: 25
# 파이리 - 체력: 25
# ----------
# 꼬부기이(가) 파이리에게 10의 데미지를 입혔습니다!
# 파이리이(가) 꼬부기에게 10의 데미지를 입혔습니다!
# 꼬부기 - 체력: 15
# 파이리 - 체력: 15
# ----------
# 꼬부기이(가) 파이리에게 15의 데미지를 입혔습니다!
# 파이리가 쓰러졌습니다! 꼬부기 승리!

# %%
class Pokemon:
    def __init__(self, name, level=5):
        self.name = name
        self.level = level
        self.hp = level * 10

    def attack(self, opponent):
        damage = self.level * random.randint(1, 3)
        print(f"{self.name}이(가) {opponent.name}에게 {damage}의 데미지를 입혔습니다!")
        opponent.hp -= damage

    def is_knocked_out(self):
        return self.hp <= 0

    def status(self):
        print(f"{self.name} - 체력: {self.hp}")

kobugi = Pokemon("꼬부기", level=5)
pairi = Pokemon("파이리", level=5)

print("배틀 시작")
while True:
    kobugi.attack(pairi)
    if pairi.is_knocked_out():
        print(f"{pairi.name}가 쓰러졌습니다! {kobugi.name} 승리!")
        break

    pairi.attack(kobugi)
    if kobugi.is_knocked_out():
        print(f"{kobugi.name}가 쓰러졌습니다! {pairi.name} 승리!")
        break

    kobugi.status()
    pairi.status()
    print("--------")
# Out:
# 배틀 시작
# 꼬부기이(가) 파이리에게 5의 데미지를 입혔습니다!
# 파이리이(가) 꼬부기에게 10의 데미지를 입혔습니다!
# 꼬부기 - 체력: 40
# 파이리 - 체력: 45
# --------
# 꼬부기이(가) 파이리에게 10의 데미지를 입혔습니다!
# 파이리이(가) 꼬부기에게 15의 데미지를 입혔습니다!
# 꼬부기 - 체력: 25
# 파이리 - 체력: 35
# --------
# 꼬부기이(가) 파이리에게 5의 데미지를 입혔습니다!
# 파이리이(가) 꼬부기에게 10의 데미지를 입혔습니다!
# 꼬부기 - 체력: 15
# 파이리 - 체력: 30
# --------
# 꼬부기이(가) 파이리에게 5의 데미지를 입혔습니다!
# 파이리이(가) 꼬부기에게 5의 데미지를 입혔습니다!
# 꼬부기 - 체력: 10
# 파이리 - 체력: 25
# --------
# 꼬부기이(가) 파이리에게 10의 데미지를 입혔습니다!
# 파이리이(가) 꼬부기에게 5의 데미지를 입혔습니다!
# 꼬부기 - 체력: 5
# 파이리 - 체력: 15
# --------
# 꼬부기이(가) 파이리에게 10의 데미지를 입혔습니다!
# 파이리이(가) 꼬부기에게 5의 데미지를 입혔습니다!
# 꼬부기가 쓰러졌습니다! 파이리 승리!

# %%
import random

# 포켓몬 클래스 정의
class Pokemon:
    def __init__(self, name, level=5):
        self.name = name            # 포켓몬 이름
        self.level = level          # 포켓몬 레벨 (기본값 5)
        self.hp = level * 10        # 체력은 레벨에 따라 결정 (예: 레벨 5면 체력 50)

    def attack(self, opponent):
        # 간단한 공격: 데미지는 레벨과 1부터 3 사이의 랜덤 숫자를 곱해 결정합니다.
        damage = self.level * random.randint(1, 3)
        print(f"{self.name}이(가) {opponent.name}에게 {damage}의 데미지를 입혔습니다!")
        opponent.hp -= damage

    def is_knocked_out(self):
        # 체력이 0 이하이면 쓰러진 것으로 간주
        return self.hp <= 0

    def status(self):
        # 현재 상태(이름과 체력)를 출력하는 메서드
        print(f"{self.name} - 체력: {self.hp}")

# 1부터 45까지의 숫자로 포켓몬 이름 생성
pokemon_names = [str(i) for i in range(1, 46)]

# 45마리 포켓몬 생성
pokemons = [Pokemon(name, level=random.randint(1, 10)) for name in pokemon_names]

# 배틀 시뮬레이션 시작
print("배틀 시작!")
while len(pokemons) > 1:
    attacker = random.choice(pokemons)
    opponent = random.choice([p for p in pokemons if p != attacker])

    attacker.attack(opponent)

    if opponent.is_knocked_out():
        print(f"{opponent.name}가 쓰러졌습니다! {attacker.name} 승리!")
        pokemons.remove(opponent)

    # 각 포켓몬의 현재 체력을 출력
    for pokemon in pokemons:
        pokemon.status()
    print("----------")

# 최종 승리 포켓몬 출력
if pokemons:
    print(f"최종 승리 포켓몬: {pokemons[0].name}!")
# Out:
# 배틀 시작!
# 25이(가) 28에게 3의 데미지를 입혔습니다!
# 1 - 체력: 90
# 2 - 체력: 60
# 3 - 체력: 80
# 4 - 체력: 80
# 5 - 체력: 60
# 6 - 체력: 80
# 7 - 체력: 70
# 8 - 체력: 70
# 9 - 체력: 90
# 10 - 체력: 60
# 11 - 체력: 50
# 12 - 체력: 60
# 13 - 체력: 70
# 14 - 체력: 20
# 15 - 체력: 20
# 16 - 체력: 80
# 17 - 체력: 40
# 18 - 체력: 100
# 19 - 체력: 30
# 20 - 체력: 10
# 21 - 체력: 90
# 22 - 체력: 10
# 23 - 체력: 20
# 24 - 체력: 30
# 25 - 체력: 30
# 26 - 체력: 60
# 27 - 체력: 10
# 28 - 체력: 97
# 29 - 체력: 20
# 30 - 체력: 100
# 31 - 체력: 60
# 32 - 체력: 90
# 33 - 체력: 20
# 34 - 체력: 40
# 35 - 체력: 20
# 36 - 체력: 20
# 37 - 체력: 100
# 38 - 체력: 40
# 39 - 체력: 30
# 40 - 체력: 60
# 41 - 체력: 100
# 42 - 체력: 80
# 43 - 체력: 60
# 44 - 체력: 10
# 45 - 체력: 20
# ----------
# 5이(가) 4에게 6의 데미지를 입혔습니다!
# 1 - 체력: 90
# 2 - 체력: 60
# 3 - 체력: 80
# 4 - 체력: 74
# 5 - 체력: 60
# 6 - 체력: 80
# 7 - 체력: 70
# 8 - 체력: 70
# 9 - 체력: 90
# 10 - 체력: 60
# 11 - 체력: 50
# 12 - 체력: 60
# 13 - 체력: 70
# 14 - 체력: 20
# 15 - 체력: 20
# 16 - 체력: 80
# 17 - 체력: 40
# 18 - 체력: 100
# 19 - 체력: 30
# 20 - 체력: 10
# 21 - 체력: 90
# ...

# %%
import random

# 포켓몬 클래스 정의
class Pokemon:
    def __init__(self, name, level=5):
        self.name = name            # 포켓몬 이름
        self.level = level          # 포켓몬 레벨 (기본값 5)
        self.hp = level * 10        # 체력은 레벨에 따라 결정 (예: 레벨 5면 체력 50)

    def attack(self, opponent):
        # 간단한 공격: 데미지는 레벨과 1부터 3 사이의 랜덤 숫자를 곱해 결정합니다.
        damage = self.level * random.randint(1, 3)
        print(f"{self.name}이(가) {opponent.name}에게 {damage}의 데미지를 입혔습니다!")
        opponent.hp -= damage

    def is_knocked_out(self):
        # 체력이 0 이하이면 쓰러진 것으로 간주
        return self.hp <= 0

    def status(self):
        # 현재 상태(이름과 체력)를 출력하는 메서드
        print(f"{self.name} - 체력: {self.hp}")

# 1부터 45까지의 숫자로 포켓몬 이름 생성
pokemon_names = [str(i) for i in range(1, 46)]

# 45마리 포켓몬 생성
pokemons = [Pokemon(name, level=random.randint(1, 10)) for name in pokemon_names]

# 배틀 시뮬레이션 시작
print("배틀 시작!")
eliminated = []  # 쓰러진 포켓몬을 저장할 리스트
while len(pokemons) > 1:
    attacker = random.choice(pokemons)
    opponent = random.choice([p for p in pokemons if p != attacker])

    attacker.attack(opponent)

    if opponent.is_knocked_out():
        print(f"{opponent.name}가 쓰러졌습니다! {attacker.name} 승리!")
        eliminated.append(opponent)  # 쓰러진 포켓몬 추가
        pokemons.remove(opponent)

    # 각 포켓몬의 현재 체력을 출력
    for pokemon in pokemons:
        pokemon.status()
    print("----------")

# 최종 승리 포켓몬 출력
if pokemons:
    print(f"최종 승리 포켓몬: {pokemons[0].name}!")

# 1위부터 6위까지의 포켓몬 출력
print("최종 순위:")
for i in range(min(6, len(eliminated))):
    print(f"{i + 1}위: {eliminated[-(i + 1)].name}")

# 만약 6위보다 적은 포켓몬이 쓰러졌다면 남은 포켓몬도 출력
if len(eliminated) < 6:
    for i in range(len(eliminated), 6):
        print(f"{i + 1}위: 남은 포켓몬 없음")
# Out:
# 배틀 시작!
# 30이(가) 11에게 16의 데미지를 입혔습니다!
# 1 - 체력: 60
# 2 - 체력: 100
# 3 - 체력: 80
# 4 - 체력: 100
# 5 - 체력: 50
# 6 - 체력: 30
# 7 - 체력: 80
# 8 - 체력: 20
# 9 - 체력: 90
# 10 - 체력: 50
# 11 - 체력: 24
# 12 - 체력: 10
# 13 - 체력: 90
# 14 - 체력: 10
# 15 - 체력: 60
# 16 - 체력: 30
# 17 - 체력: 20
# 18 - 체력: 10
# 19 - 체력: 20
# 20 - 체력: 50
# 21 - 체력: 10
# 22 - 체력: 50
# 23 - 체력: 20
# 24 - 체력: 10
# 25 - 체력: 50
# 26 - 체력: 30
# 27 - 체력: 50
# 28 - 체력: 50
# 29 - 체력: 70
# 30 - 체력: 80
# 31 - 체력: 50
# 32 - 체력: 20
# 33 - 체력: 90
# 34 - 체력: 80
# 35 - 체력: 10
# 36 - 체력: 90
# 37 - 체력: 50
# 38 - 체력: 90
# 39 - 체력: 30
# 40 - 체력: 10
# 41 - 체력: 40
# 42 - 체력: 100
# 43 - 체력: 20
# 44 - 체력: 10
# 45 - 체력: 50
# ----------
# 28이(가) 5에게 10의 데미지를 입혔습니다!
# 1 - 체력: 60
# 2 - 체력: 100
# 3 - 체력: 80
# 4 - 체력: 100
# 5 - 체력: 40
# 6 - 체력: 30
# 7 - 체력: 80
# 8 - 체력: 20
# 9 - 체력: 90
# 10 - 체력: 50
# 11 - 체력: 24
# 12 - 체력: 10
# 13 - 체력: 90
# 14 - 체력: 10
# 15 - 체력: 60
# 16 - 체력: 30
# 17 - 체력: 20
# 18 - 체력: 10
# 19 - 체력: 20
# 20 - 체력: 50
# 21 - 체력: 10
# ...

# %%
import random

# 포켓몬 클래스 정의
class Pokemon:
    def __init__(self, name, level=5):
        self.name = name            # 포켓몬 이름
        self.level = level          # 포켓몬 레벨 (기본값 5)
        self.hp = level * 10        # 체력은 레벨에 따라 결정 (예: 레벨 5면 체력 50)

    def attack(self, opponent):
        # 간단한 공격: 데미지는 레벨과 1부터 3 사이의 랜덤 숫자를 곱해 결정합니다.
        damage = self.level * random.randint(1, 3)
        print(f"{self.name}이(가) {opponent.name}에게 {damage}의 데미지를 입혔습니다!")
        opponent.hp -= damage

    def is_knocked_out(self):
        # 체력이 0 이하이면 쓰러진 것으로 간주
        return self.hp <= 0

    def status(self):
        # 현재 상태(이름과 체력)를 출력하는 메서드
        print(f"{self.name} - 체력: {self.hp}")

# 1부터 45까지의 숫자로 포켓몬 이름 생성
pokemon_names = [str(i) for i in range(1, 46)]

# 45마리 포켓몬 생성
pokemons = [Pokemon(name, level=random.randint(1, 10)) for name in pokemon_names]

# 배틀 시뮬레이션 시작
print("배틀 시작!")
eliminated = []  # 쓰러진 포켓몬을 저장할 리스트
while len(pokemons) > 1:
    attacker = random.choice(pokemons)
    opponent = random.choice([p for p in pokemons if p != attacker])

    attacker.attack(opponent)

    if opponent.is_knocked_out():
        print(f"{opponent.name}가 쓰러졌습니다! {attacker.name} 승리!")
        eliminated.append(opponent)  # 쓰러진 포켓몬 추가
        pokemons.remove(opponent)

    # 각 포켓몬의 현재 체력을 출력
    for pokemon in pokemons:
        pokemon.status()
    print("----------")

# 최종 승리 포켓몬 출력
if pokemons:
    print(f"최종 승리 포켓몬: {pokemons[0].name}!")

# 1위부터 6위까지의 포켓몬 출력
print("최종 순위:")
for i in range(min(6, len(eliminated))):
    print(f"{i + 1}위: {eliminated[-(i + 1)].name}")

# 만약 6위보다 적은 포켓몬이 쓰러졌다면 남은 포켓몬도 출력
if len(eliminated) < 6:
    for i in range(len(eliminated), 6):
        print(f"{i + 1}위: 남은 포켓몬 없음")
# Out:
# 배틀 시작!
# 6이(가) 1에게 8의 데미지를 입혔습니다!
# 1 - 체력: 2
# 2 - 체력: 60
# 3 - 체력: 40
# 4 - 체력: 40
# 5 - 체력: 40
# 6 - 체력: 80
# 7 - 체력: 60
# 8 - 체력: 40
# 9 - 체력: 80
# 10 - 체력: 90
# 11 - 체력: 80
# 12 - 체력: 50
# 13 - 체력: 10
# 14 - 체력: 50
# 15 - 체력: 80
# 16 - 체력: 70
# 17 - 체력: 70
# 18 - 체력: 70
# 19 - 체력: 100
# 20 - 체력: 70
# 21 - 체력: 90
# 22 - 체력: 80
# 23 - 체력: 10
# 24 - 체력: 10
# 25 - 체력: 30
# 26 - 체력: 60
# 27 - 체력: 20
# 28 - 체력: 90
# 29 - 체력: 80
# 30 - 체력: 80
# 31 - 체력: 90
# 32 - 체력: 40
# 33 - 체력: 10
# 34 - 체력: 50
# 35 - 체력: 20
# 36 - 체력: 100
# 37 - 체력: 100
# 38 - 체력: 100
# 39 - 체력: 80
# 40 - 체력: 20
# 41 - 체력: 40
# 42 - 체력: 100
# 43 - 체력: 40
# 44 - 체력: 50
# 45 - 체력: 70
# ----------
# 28이(가) 45에게 27의 데미지를 입혔습니다!
# 1 - 체력: 2
# 2 - 체력: 60
# 3 - 체력: 40
# 4 - 체력: 40
# 5 - 체력: 40
# 6 - 체력: 80
# 7 - 체력: 60
# 8 - 체력: 40
# 9 - 체력: 80
# 10 - 체력: 90
# 11 - 체력: 80
# 12 - 체력: 50
# 13 - 체력: 10
# 14 - 체력: 50
# 15 - 체력: 80
# 16 - 체력: 70
# 17 - 체력: 70
# 18 - 체력: 70
# 19 - 체력: 100
# 20 - 체력: 70
# 21 - 체력: 90
# ...

# %%
import random

# 포켓몬 클래스 정의
class Pokemon:
    def __init__(self, name, level=5):
        self.name = name            # 포켓몬 이름
        self.level = level          # 포켓몬 레벨 (기본값 5)
        self.hp = level * 10        # 체력은 레벨에 따라 결정 (예: 레벨 5면 체력 50)

    def attack(self, opponent):
        # 간단한 공격: 데미지는 레벨과 1부터 3 사이의 랜덤 숫자를 곱해 결정합니다.
        damage = self.level * random.randint(1, 3)
        print(f"{self.name}이(가) {opponent.name}에게 {damage}의 데미지를 입혔습니다!")
        opponent.hp -= damage

    def is_knocked_out(self):
        # 체력이 0 이하이면 쓰러진 것으로 간주
        return self.hp <= 0

    def status(self):
        # 현재 상태(이름과 체력)를 출력하는 메서드
        print(f"{self.name} - 체력: {self.hp}")

# 1부터 45까지의 숫자로 포켓몬 이름 생성
pokemon_names = [str(i) for i in range(1, 46)]

# 45마리 포켓몬 생성
pokemons = [Pokemon(name, level=random.randint(1, 10)) for name in pokemon_names]

# 배틀 시뮬레이션 시작
print("배틀 시작!")
eliminated = []  # 쓰러진 포켓몬을 저장할 리스트
while len(pokemons) > 1:
    attacker = random.choice(pokemons)
    opponent = random.choice([p for p in pokemons if p != attacker])

    attacker.attack(opponent)

    if opponent.is_knocked_out():
        print(f"{opponent.name}가 쓰러졌습니다! {attacker.name} 승리!")
        eliminated.append(opponent)  # 쓰러진 포켓몬 추가
        pokemons.remove(opponent)

    # 각 포켓몬의 현재 체력을 출력
    for pokemon in pokemons:
        pokemon.status()
    print("----------")

# 최종 승리 포켓몬 출력
if pokemons:
    print(f"최종 승리 포켓몬: {pokemons[0].name}!")

# 1위부터 6위까지의 포켓몬 출력
print("최종 순위:")
for i in range(min(6, len(eliminated))):
    print(f"{i + 1}위: {eliminated[-(i + 1)].name}")

# 만약 6위보다 적은 포켓몬이 쓰러졌다면 남은 포켓몬도 출력
if len(eliminated) < 6:
    for i in range(len(eliminated), 6):
        print(f"{i + 1}위: 남은 포켓몬 없음")
# Out:
# 배틀 시작!
# 23이(가) 25에게 1의 데미지를 입혔습니다!
# 1 - 체력: 30
# 2 - 체력: 50
# 3 - 체력: 40
# 4 - 체력: 50
# 5 - 체력: 40
# 6 - 체력: 20
# 7 - 체력: 30
# 8 - 체력: 100
# 9 - 체력: 70
# 10 - 체력: 60
# 11 - 체력: 40
# 12 - 체력: 30
# 13 - 체력: 40
# 14 - 체력: 100
# 15 - 체력: 70
# 16 - 체력: 40
# 17 - 체력: 60
# 18 - 체력: 70
# 19 - 체력: 40
# 20 - 체력: 30
# 21 - 체력: 90
# 22 - 체력: 70
# 23 - 체력: 10
# 24 - 체력: 50
# 25 - 체력: 29
# 26 - 체력: 100
# 27 - 체력: 20
# 28 - 체력: 40
# 29 - 체력: 50
# 30 - 체력: 70
# 31 - 체력: 80
# 32 - 체력: 60
# 33 - 체력: 50
# 34 - 체력: 50
# 35 - 체력: 60
# 36 - 체력: 10
# 37 - 체력: 100
# 38 - 체력: 20
# 39 - 체력: 10
# 40 - 체력: 20
# 41 - 체력: 70
# 42 - 체력: 60
# 43 - 체력: 70
# 44 - 체력: 40
# 45 - 체력: 40
# ----------
# 30이(가) 10에게 14의 데미지를 입혔습니다!
# 1 - 체력: 30
# 2 - 체력: 50
# 3 - 체력: 40
# 4 - 체력: 50
# 5 - 체력: 40
# 6 - 체력: 20
# 7 - 체력: 30
# 8 - 체력: 100
# 9 - 체력: 70
# 10 - 체력: 46
# 11 - 체력: 40
# 12 - 체력: 30
# 13 - 체력: 40
# 14 - 체력: 100
# 15 - 체력: 70
# 16 - 체력: 40
# 17 - 체력: 60
# 18 - 체력: 70
# 19 - 체력: 40
# 20 - 체력: 30
# 21 - 체력: 90
# ...

# %%
import random

# 포켓몬 클래스 정의
class Pokemon:
    def __init__(self, name, level=5):
        self.name = name            # 포켓몬 이름
        self.level = level          # 포켓몬 레벨 (기본값 5)
        self.hp = level * 10        # 체력은 레벨에 따라 결정 (예: 레벨 5면 체력 50)

    def attack(self, opponent):
        # 간단한 공격: 데미지는 레벨과 1부터 3 사이의 랜덤 숫자를 곱해 결정합니다.
        damage = self.level * random.randint(1, 3)
        print(f"{self.name}이(가) {opponent.name}에게 {damage}의 데미지를 입혔습니다!")
        opponent.hp -= damage

    def is_knocked_out(self):
        # 체력이 0 이하이면 쓰러진 것으로 간주
        return self.hp <= 0

    def status(self):
        # 현재 상태(이름과 체력)를 출력하는 메서드
        print(f"{self.name} - 체력: {self.hp}")

# 1부터 45까지의 숫자로 포켓몬 이름 생성
pokemon_names = [str(i) for i in range(1, 46)]

# 45마리 포켓몬 생성
pokemons = [Pokemon(name, level=random.randint(1, 10)) for name in pokemon_names]

# 배틀 시뮬레이션 시작
print("배틀 시작!")
eliminated = []  # 쓰러진 포켓몬을 저장할 리스트
while len(pokemons) > 1:
    attacker = random.choice(pokemons)
    opponent = random.choice([p for p in pokemons if p != attacker])

    attacker.attack(opponent)

    if opponent.is_knocked_out():
        print(f"{opponent.name}가 쓰러졌습니다! {attacker.name} 승리!")
        eliminated.append(opponent)  # 쓰러진 포켓몬 추가
        pokemons.remove(opponent)

    # 각 포켓몬의 현재 체력을 출력
    for pokemon in pokemons:
        pokemon.status()
    print("----------")

# 최종 승리 포켓몬 출력
if pokemons:
    print(f"최종 승리 포켓몬: {pokemons[0].name}!")

# 1위부터 6위까지의 포켓몬 출력
print("최종 순위:")
for i in range(min(6, len(eliminated))):
    print(f"{i + 1}위: {eliminated[-(i + 1)].name}")

# 만약 6위보다 적은 포켓몬이 쓰러졌다면 남은 포켓몬도 출력
if len(eliminated) < 6:
    for i in range(len(eliminated), 6):
        print(f"{i + 1}위: 남은 포켓몬 없음")
# Out:
# 배틀 시작!
# 45이(가) 14에게 9의 데미지를 입혔습니다!
# 1 - 체력: 40
# 2 - 체력: 60
# 3 - 체력: 80
# 4 - 체력: 50
# 5 - 체력: 30
# 6 - 체력: 20
# 7 - 체력: 70
# 8 - 체력: 70
# 9 - 체력: 20
# 10 - 체력: 60
# 11 - 체력: 80
# 12 - 체력: 90
# 13 - 체력: 60
# 14 - 체력: 91
# 15 - 체력: 100
# 16 - 체력: 10
# 17 - 체력: 10
# 18 - 체력: 100
# 19 - 체력: 30
# 20 - 체력: 20
# 21 - 체력: 30
# 22 - 체력: 50
# 23 - 체력: 50
# 24 - 체력: 40
# 25 - 체력: 50
# 26 - 체력: 50
# 27 - 체력: 70
# 28 - 체력: 40
# 29 - 체력: 100
# 30 - 체력: 60
# 31 - 체력: 100
# 32 - 체력: 60
# 33 - 체력: 30
# 34 - 체력: 80
# 35 - 체력: 70
# 36 - 체력: 50
# 37 - 체력: 70
# 38 - 체력: 50
# 39 - 체력: 80
# 40 - 체력: 60
# 41 - 체력: 30
# 42 - 체력: 90
# 43 - 체력: 100
# 44 - 체력: 20
# 45 - 체력: 90
# ----------
# 14이(가) 5에게 10의 데미지를 입혔습니다!
# 1 - 체력: 40
# 2 - 체력: 60
# 3 - 체력: 80
# 4 - 체력: 50
# 5 - 체력: 20
# 6 - 체력: 20
# 7 - 체력: 70
# 8 - 체력: 70
# 9 - 체력: 20
# 10 - 체력: 60
# 11 - 체력: 80
# 12 - 체력: 90
# 13 - 체력: 60
# 14 - 체력: 91
# 15 - 체력: 100
# 16 - 체력: 10
# 17 - 체력: 10
# 18 - 체력: 100
# 19 - 체력: 30
# 20 - 체력: 20
# 21 - 체력: 30
# ...

# %%
class MyClass():
    name = 'kim'

    def hello(self):
        return 'hihihihi'

# %%
m = MyClass()

# %%
print(type(m))
# Out:
# <class '__main__.MyClass'>

# %%
print(m.name)
print(m.hello())
# Out:
# kim
# hihihihi

# %%
m2 = MyClass()
print(m2.name)
print(m2.hello())
# Out:
# kim
# hihihihi

# %%
m2.name = 'park'

print(m.name)
print(m2.name)
# Out:
# kim
# park

# %%
class Phone():
    power = False
    number = '010-0000-0000'
    book = {}
    model = ''

    def on(self):
        if self.power == False:
            self.power = True

    def off(self):
        if self.power == True:
            self.power = False

    def call(self, target):
        if self.power == True:
            print(f'{self.number}가 {target.number}한테 전화거는 중')
        else:
            print('핸드폰이 꺼져있습니다.')

# %%
my_phone = Phone()
your_phone = Phone()

# %%
my_phone.number
# Out:
# '010-0000-0000'

# %%
my_phone.number = '010-1234-1234'
print(my_phone.number)
# Out:
# 010-1234-1234

# %%
my_phone.power
# Out:
# False

# %%
my_phone.on()

# %%
my_phone.power
# Out:
# True

# %%
your_phone.power
# Out:
# False

# %%
my_phone.call(your_phone)
# Out:
# 010-1234-1234가 010-0000-0000한테 전화거는 중

# %%
your_phone.call(my_phone)
# Out:
# 핸드폰이 꺼져있습니다.

# %%
class Person():
    name = ''
    gender = ''
    age = 0
    height = 0

    def greeting(self):
        print(f'안녕하세요. 나는 {self.name}입니다.')

    def grow(self):
        self.age += 1

# %%
p1 = Person()
p2 = Person()

# %%
print(p1.name, p2.name)

# %%
p1.name = 'hong'
p2.name = 'kim'

p1.gender = 'F'
p2.gender = 'M'

p1.age = 20
p2.age = 30

p1.height = 170
p2.height = 180

# %%
p1.greeting()
# Out:
# 안녕하세요. 나는 hong입니다.

# %%
Person.greeting(p1)
# Out:
# 안녕하세요. 나는 hong입니다.

# %%
class Person():
    name = ''

    def __init__(self, n):
        self.name = n
        print('생성됨')

    def __del__(self):
        print('소멸됨')

# %%
p1 = Person('kim')
p2 = Person('park')
# Out:
# 생성됨
# 생성됨

# %%
class Circle():
    pi = 3.14

    def __init__(self, r, x=0, y=0):
        self.r = r
        self.x = x
        self.y = y

    def info(self):
        print(f'반지름: {self.r}, 중심점: {self.x}, {self.y}')

    def area(self):
        return self.r ** 2 * self.pi

    def round(self):
        return self.r * self.pi * 2

    def move(self, x, y):
        self.x = x
        self.y = y

# %%
c1 = Circle(5)
c2 = Circle(3, 1, 1)

# %%
c1.info()
c2.info()
# Out:
# 반지름: 5, 중심점: 0, 0
# 반지름: 3, 중심점: 1, 1

# %%
print(c1.area())
print(c2.area())
# Out:
# 78.5
# 28.26

# %%
c1.round()
# Out:
# 31.400000000000002

# %%
c1.move(100, 100)
c1.info()
# Out:
# 반지름: 5, 중심점: 100, 100

# %%
class Point():
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def info(self):
        print(f'{self.x}, {self.y}')

# %%
p1 = Point(1, 1)
p2 = Point(2, 3)
# Out:
# 소멸됨
# 소멸됨

# %%
import random

def russian_roulette():
    # 총알이 장전된 위치를 랜덤으로 선택
    bullet_position = random.randint(1, 6)
    print("러시안 룰렛 게임에 오신 것을 환영합니다!")
    
    for turn in range(1, 7):
        print(f"\n턴 {turn}: 방아쇠를 당깁니다...")
        if turn == bullet_position:
            print("빵! 당신은 죽었습니다!")
            break
        else:
            print("휴... 살아남았습니다!")
    else:
        print("모든 턴을 무사히 마쳤습니다!")

# 게임 시작
russian_roulette()
# Out:
# 러시안 룰렛 게임에 오신 것을 환영합니다!
#
# 턴 1: 방아쇠를 당깁니다...
# 휴... 살아남았습니다!
#
# 턴 2: 방아쇠를 당깁니다...
# 휴... 살아남았습니다!
#
# 턴 3: 방아쇠를 당깁니다...
# 휴... 살아남았습니다!
#
# 턴 4: 방아쇠를 당깁니다...
# 휴... 살아남았습니다!
#
# 턴 5: 방아쇠를 당깁니다...
# 휴... 살아남았습니다!
#
# 턴 6: 방아쇠를 당깁니다...
# 빵! 당신은 죽었습니다!

# %%
import random

# 과거 로또 당첨 번호 (예시)
past_winning_numbers = [
    [1, 3, 23, 24, 27, 40],
    [2, 5, 12, 19, 28, 45],
    [3, 11, 15, 22, 34, 42],
    # 추가적인 과거 번호를 여기에 추가
]

def generate_lotto_numbers(past_numbers):
    # 과거 번호에서 번호를 추출
    all_numbers = [num for sublist in past_numbers for num in sublist]
    
    # 중복 제거
    unique_numbers = list(set(all_numbers))
    
    # 무작위로 6개의 번호 선택
    return random.sample(unique_numbers, 6)

# 이번 주 로또 번호 생성
new_lotto_numbers = generate_lotto_numbers(past_winning_numbers)
print("이번 주 로또 번호:", sorted(new_lotto_numbers))
# Out:
# 이번 주 로또 번호: [1, 3, 15, 24, 27, 34]
