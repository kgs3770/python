# %%
num = int(input("정수를 입력하세요: "))

if num % 2 == 0:
    print("짝수입니다.")
else:
    print("홀수입니다.")

# %%
score = int(input("점수를 입력하세요: "))

if score >= 90:
    print("A")
elif score >= 80:
    print("B")
elif score >= 70:
    print("C")
elif score >= 60:
    print("D")
else:
    print("F")

# %%
score = int(input())

if score >= 90:
    print('A')
    if score >= 95:
        print('good!!!')
elif score >= 80:
    print('B')
elif score >= 70:
    print('C')
else:
    print('F')

# %%
for i in range(5):
    print(i)

# %%
numbers = range(1, 51)

for number in numbers:
    if number % 5 == 0:
        print(number)

# %%
locations = ['서울', '대전', '부산']
for (index, location) in enumerate(locations):
    print(index)
    print(location)

# %%
num = int(input('정수입력'))

if num > 0:
    print('양수.')
else:
    print('음수.')

# %%
num = int(input('정수 입력:'))

if num % 2 == 0:
    print('짝수')
else:
    print('홀수')

# %%
num1 = int(input('첫번째 정수'))
num2 = int(input('두번째 정수'))

if num1 > num2:
    print(num1)
else:
    print(num2)

# %%
year = int(input('연도 입력'))

if (year % 4 == 0 and year % 100 !=0) or (year % 400 == 0):
    print('윤년')
else:
    print('평년')

# %%
num = int(input('정수입력'))

if 1 <= num <= 100:
    print('1과 100사이')
else:
    print('1과 100사이 아님')

# %%
for i in range(1, 11):
    print(i, end=' ')

# %%
for i in range(1, 21):
    if i % 2 ==0:
        print(i, end=' ')

# %%
total = 0
for i in range(1, 101):
    total += i
print(total)

# %%
num = int(input('구구단'))

for i in range(1, 10):
    print(f'{num} x {i} = {num * i}')

# %%
height2 = 50
width2 = 50

area2 = height2 * width2
perimeter2 = (height2 + width2) * 2

# %%
height = 50
width = 20

area = height * width
perimeter = (height + width) * 2

print(f'사각형의 면적은 {area}이고 둘레는 {perimeter}입니다.')

# %%
def rectangle(height, width):
    area = height * width
    perimeter = (height + width) * 2

    print(f' 사각형의 면적은 {area}입니다. 둘레는 {perimeter}입니다.')

# %%
rectangle(50, 30)

# %%
max(100, 2)

# %%
def my_max(num1, num2):
    if num1 > num2:
        print(num1)
    elif num1 < num2:
        print(num2)
    else:
        print('같다')

# %%
my_max(5, 5)
my_max(5, 1)
my_max(1, 5)

# %%
result = my_max(1, 2)
print(result)

# %%
def my_max2(num1, num2):
    if num1 > num2:
        return num1
    else:
        return num2

# %%
result = my_max2(1, 2)
print(result)

# %%
def my_for(x):
    for i in range(x):
        print(i)
        if i == 3:
            return i

my_for(5)

# %%
def my_def(x):
    return (x * 2, x)

my_def(10)

# %%
def my_list_max(list1, list2):
    #list1 = [1, 2, 3]
    #list2 = [2, 3, 4]
    sum_of_list1 = list1[0] + list1[1] + list[2]
    sum_of_list2 = list2[0] + list2[1] + list[2]

    if sum_of_list1 > sum_oflist2:
        return list1
    else:
        return list2

# %%
my_list_max([55, 44, 22], [2, 3, 4])
# => [2, 3, 4]
# Out:
# [55, 44, 22]

# %%
# version3
def my_list_max(list1, list2):
    sum_of_list1 = sum(list1)
    sum_of_list2 = sum(list2)

    if sum_of_list1 > sum_of_list2:
        return list1
    else:
        return list2

# %%
def cylinder(r, h):
    return 3.14 * r ** 2 * h

# %%
cylinder(3, 10)
# Out:
# 282.6

# %%
cylinder(10, 3)
# Out:
# 942.0

# %%
def greeting(name='익명'):
    return f'{name}님 반갑습니다.'

# %%
greeting('')
# Out:
# '님 반갑습니다.'

# %%
a = 'hello my name is hong'

# %%
print(a)
# Out:
# hello my name is hong

# %%
a = a.capitalize()

# %%
print(a)
# Out:
# Hello my name is hong

# %%
a.title()
# Out:
# 'Hello My Name Is Hong'

# %%
a.lower()
# Out:
# 'hello my name is hong'

# %%
my_list = ['my', 'name', 'is']
'!'.join(my_list)
# Out:
# 'my!name!is'

# %%
'?'.join('배고프다')
# Out:
# '배?고?프?다'

# %%
a = '\t           hello         \n'
a.strip()
# Out:
# 'hello'

# %%
a = '!!!!hello!!!!!!'
a.strip('!')
# Out:
# 'hello'

# %%
a = '--------------hello-----------'
a.lstrip('-')
# Out:
# 'hello-----------'

# %%
a.rstrip('-')
# Out:
# '--------------hello'

# %%
a = 'woooooooooooooooow'
a.replace('o', '!', 3)
# Out:
# 'w!!!ooooooooooooow'

# %%
a = 'apple'
a. find('a')
# Out:
# 0

# %%
a = 'apple'
a. index('e')
# Out:
# 4

# %%
a = 'my name is hong'
a.split()
# Out:
# ['my', 'name', 'is', 'hong']

# %%
a = 'woooooooooooooooooow'
a.count('o')
# Out:
# 18

# %%
numbers = [2, 6, 1, 4, 8, 3, 2, 8]

# %%
numbers.append(10)
print(numbers)
# Out:
# [2, 6, 1, 4, 8, 3, 2, 8, 10]

# %%
a = [99, 100]

# %%
numbers.extend(a)
print(numbers)
# Out:
# [2, 6, 1, 4, 8, 3, 2, 8, 10, 99, 100]

# %%
numbers.insert(3, 5)
print(numbers)
# Out:
# [2, 6, 1, 5, 4, 8, 3, 2, 8, 10, 99, 100]

# %%
numbers.remove(8)
print(numbers)
# Out:
# [2, 6, 1, 5, 4, 3, 2, 10, 99, 100]

# %%
numbers.pop()
print(numbers)
# Out:
# [2, 6, 1, 5, 4, 3, 2, 10, 99]

# %%
numbers.pop(0)
print(numbers)
# Out:
# [6, 1, 5, 4, 3, 2, 10, 99]

# %%
numbers.sort(reverse=True)
print(numbers)
# Out:
# [99, 10, 6, 5, 4, 3, 2, 1]

# %%
a = [5, 3, 2, 7, 8, 1]
print(sorted(a))
print(a)
# Out:
# [1, 2, 3, 5, 7, 8]
# [5, 3, 2, 7, 8, 1]

# %%
my_list = ['a', '하', '나', 'b', 'z']
my_list.sort()
print(my_list)
# Out:
# ['a', 'b', 'z', '나', '하']

# %%
print(numbers)
numbers.reverse()
print(numbers)
# Out:
# [99, 10, 6, 5, 4, 3, 2, 1]
# [1, 2, 3, 4, 5, 6, 10, 99]

# %%
numbers.count(10)
# Out:
# 1

# %%
origin_list = [1, 2, 3]
copy_list = origin_list

# %%
print(origin_list)
print(copy_list)
# Out:
# [1, 2, 3]
# [1, 2, 3]

# %%
copy_list[0] = 100
print(origin_list)
print(copy_list)
# Out:
# [100, 2, 3]
# [100, 2, 3]

# %%
origin_list = [1, 2, 3]
copy_list = origin_list[:]

copy_list[0] = 100

print(origin_list)
print(copy_list)
# Out:
# [1, 2, 3]
# [100, 2, 3]

# %%
import random

my_numbers = {}

for i in range(1, 6):
    random_numbers = random.sample(range(1,46), 6)
    random_numbers.sort()
    my_numbers[i] = random_numbers
print(my_numbers)
# Out:
# {1: [2, 24, 25, 29, 32, 34], 2: [5, 12, 17, 25, 33, 37], 3: [5, 17, 19, 28, 32, 33], 4: [3, 15, 16, 17, 27, 37], 5: [2, 9, 23, 24, 29, 41]}

# %%
import requests

Lotto_URL = 'https://www.dhlottery.co.kr/common.do'
payload = {
    'method': 'getLottoNumber',
    'drwNo': 1159,
    
}

res = requests.get(Lotto_URL, params=payload)
lotto_dict = res.json()

print(lotto_dict)

lucky_numbers = []
bonus_number = lotto_dict['bnusNo']

for k, v in lotto_dict.items():
    if 'drwtNo' in k:
        lucky_numbers.append(v)

print(lucky_numbers)
# Out:
# {'totSellamnt': 124802304000, 'returnValue': 'success', 'drwNoDate': '2025-02-15', 'firstWinamnt': 1284854250, 'drwtNo6': 39, 'drwtNo4': 28, 'firstPrzwnerCo': 23, 'drwtNo5': 38, 'bnusNo': 7, 'firstAccumamnt': 29551647750, 'drwNo': 1159, 'drwtNo2': 9, 'drwtNo3': 27, 'drwtNo1': 3}
# [39, 28, 38, 9, 27, 3]

# %%
for my_number in my_numbers.values():
    my_number_set = set(my_number)
    lucky_numbers_set = set(lucky_numbers)

    match_count = len(my_number_set & lucky_numbers_set)

    if match_count == 6:
        print('1등!!!')
    elif match_count == 5 and bonus_number in my_number:
        print('2등!!!')

# %%
from datetime import datetime

# %%
datetime.now()
# Out:
# datetime.datetime(2025, 2, 19, 17, 12, 38, 949909)

# %%
datetime.today()
# Out:
# datetime.datetime(2025, 2, 19, 17, 12, 54, 702108)

# %%
import requests

# %%
r = requests.get('https://api.github.com/events')

# %%
print(r.text)
# Out:
# [{"id":"46720942477","type":"PushEvent","actor":{"id":65212910,"login":"Hall-1910","display_login":"Hall-1910","gravatar_id":"","url":"https://api.github.com/users/Hall-1910","avatar_url":"https://avatars.githubusercontent.com/u/65212910?"},"repo":{"id":222505696,"name":"brand22/d3","url":"https://api.github.com/repos/brand22/d3"},"payload":{"repository_id":222505696,"push_id":22736192120,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"372eab34c321301ae3a82d2a579d96c02ac76869","before":"dda658938d85e38d14abb417cdd7a099907c8675","commits":[{"sha":"372eab34c321301ae3a82d2a579d96c02ac76869","author":{"email":"65212910+Hall-1910@users.noreply.github.com","name":"Hall-1910"},"message":"m","distinct":true,"url":"https://api.github.com/repos/brand22/d3/commits/372eab34c321301ae3a82d2a579d96c02ac76869"}]},"public":true,"created_at":"2025-02-19T08:08:40Z"},{"id":"46720942485","type":"WatchEvent","actor":{"id":165921179,"login":"youdao2032","display_login":"youdao2032","gravatar_id":"","url":"https://api.github.com/users/youdao2032","avatar_url":"https://avatars.githubusercontent.com/u/165921179?"},"repo":{"id":213527020,"name":"wuxingsanren/wildcat-vip-account","url":"https://api.github.com/repos/wuxingsanren/wildcat-vip-account"},"payload":{"action":"started"},"public":true,"created_at":"2025-02-19T08:08:40Z"},{"id":"46720942476","type":"WatchEvent","actor":{"id":108665755,"login":"weathyII","display_login":"weathyII","gravatar_id":"","url":"https://api.github.com/users/weathyII","avatar_url":"https://avatars.githubusercontent.com/u/108665755?"},"repo":{"id":919049836,"name":"ShirakawaSanae/USTC-Compile24Fall","url":"https://api.github.com/repos/ShirakawaSanae/USTC-Compile24Fall"},"payload":{"action":"started"},"public":true,"created_at":"2025-02-19T08:08:40Z"},{"id":"46720942478","type":"PullRequestReviewEvent","actor":{"id":13559066,"login":"bandana147","display_login":"bandana147","gravatar_id":"","url":"https://api.github.com/users/bandana147","avatar_url":"https://avatars.githubusercontent.com/u/13559066?"},"repo":{"id":472064898,"name":"adobecom/milo","url":"https://api.github.com/repos/adobecom/milo"},"payload":{"action":"created","review":{"id":2625954870,"node_id":"PRR_kwDOHCMjgs6chOQ2","user":{"login":"bandana147","id":13559066,"node_id":"MDQ6VXNlcjEzNTU5MDY2","avatar_url":"https://avatars.githubusercontent.com/u/13559066?v=4","gravatar_id":"","url":"https://api.github.com/users/bandana147","html_url":"https://github.com/bandana147","followers_url":"https://api.github.com/users/bandana147/followers","following_url":"https://api.github.com/users/bandana147/following{/other_user}","gists_url":"https://api.github.com/users/bandana147/gists{/gist_id}","starred_url":"https://api.github.com/users/bandana147/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/bandana147/subscriptions","organizations_url":"https://api.github.com/users/bandana147/orgs","repos_url":"https://api.github.com/users/bandana147/repos","events_url":"https://api.github.com/users/bandana147/events{/privacy}","received_events_url":"https://api.github.com/users/bandana147/received_events","type":"User","user_view_type":"public","site_admin":false},"body":null,"commit_id":"2cf461b63113cc56dc569efefc71f9ab48709291","submitted_at":"2025-02-19T08:08:39Z","state":"approved","html_url":"https://github.com/adobecom/milo/pull/3691#pullrequestreview-2625954870","pull_request_url":"https://api.github.com/repos/adobecom/milo/pulls/3691","author_association":"CONTRIBUTOR","_links":{"html":{"href":"https://github.com/adobecom/milo/pull/3691#pullrequestreview-2625954870"},"pull_request":{"href":"https://api.github.com/repos/adobecom/milo/pulls/3691"}}},"pull_request":{"url":"https://api.github.com/repos/adobecom/milo/pulls/3691","id":2336249660,"node_id":"PR_kwDOHCMjgs6LQFc8","html_url":"https://github.com/adobecom/milo/pull/3691","diff_url":"https://github.com/adobecom/milo/pull/3691.diff","patch_url":"https://github.com/adobecom/milo/pull/ ...
