# %% [markdown]
# # 객체지향 프로그래밍 (OOP)
#
# - 클래스(class) : 같은 종류의 집단에 속하는 `속성`과 `행동`을 정의한 것
# - 속성(attribute) : 클래스/인스턴스가 가지고 있는 데이터/값
# - 행동(method) : 클래스/인스턴스가 가지고 있는 함수/기능
# - 인스턴스(instance) : 클래스를 실제로 메모리상에 할당한 것

# %%
number = 1 + 2j

# %%
print(type(number))
# Out:
# <class 'complex'>

# %%
print(number.real) 
print(number.imag)
# Out:
# 1.0
# 2.0

# %%
numbers = [1, 2, 3]

# %%
print(type(numbers))
# Out:
# <class 'list'>

# %%
numbers.reverse() #함수 실행시 ()
print(numbers)
# Out:
# [1, 2, 3]

# %%
number_2 = '010-4321-4321'
power_2 = True
phone_book = {
    'kim': '010-1111-1111',
    'park': '010-2222-2222',

}

def call(from_num, to_num): 
    print(f'{from_num}가 {to_num}한테 거는 중')

call(num,phone_book['kim'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 12
#       9 def call(from_num, to_num):
#      10     print(f'{from_num}가 {to_num}한테 거는 중')
# ---> 12 call(num,phone_book['kim'])
#
# NameError: name 'num' is not defined

# %% [markdown]
# ## class
#
# - 클래스 선언/정의
# ```python
# class className():
#     attribute2 = value1
#     attribute2 = value2
#     ...
#
#     def method_name1(self):
#         code
#
#     def method_name2(self):
#         code
#     ...
# ```
# - 인스턴스화 (클래스 실행)
# ```python
#
# c = ClassName()

# %%
# 선언
class MyClass():
    name = 'kim'

    def hello(self):
        return 'hihihihihi'

# %%
# 인스턴스화
m = MyClass()

# %%
print(type(m))
# Out:
# <class '__main__.MyClass'>

# %%
print(m.name)
print(m.hello())
# Out:
# kim
# hihihihihi

# %%
m2 = MyClass()
print(m2.name)
print(m2.hello())
# Out:
# kim
# hihihihihi

# %%
m2.name = 'park'

print(m.name)
print(m2.name)
# Out:
# kim
# park

# %%
class Phone():
    power = False
    number = '010-0000-0000'
    book = {}
    model = ''

    def on(self):
        if self.power == False:
            self.power = True

    def off(self):
        if self.power == True:
            self.power = False

    def call(self, target):
        if self.power == True:
            print(f'{self.number}가 {target.number}한테 전화거는중...')
        else:
            print('핸드폰이 꺼져있습니다.')

# %%
my_phone = Phone()
your_phone = Phone()

# %%
my_phone.number
# Out:
# '010-0000-0000'

# %%
your_phone.number
# Out:
# '010-0000-0000'

# %%
my_phone.number = '010-1234-1234'
print(my_phone.number)
# Out:
# 010-1234-1234

# %%
my_phone.power
# Out:
# False

# %%
my_phone.on()

# %%
my_phone.power
# Out:
# True

# %%
your_phone.power
# Out:
# False

# %%
my_phone.call(your_phone)
# Out:
# 010-1234-1234가 010-0000-0000한테 전화거는중...

# %%
your_phone.call(my_phone)
# Out:
# 핸드폰이 꺼져있습니다

# %%
class Person():
    name = ''
    gender = ''
    age = 0
    height = 0

    def greeting(self):
        print(f'안녕하세요. 나는 {self.name}입니다.')

    def grow(self):
        self.age += 1

# %%
p1 = Person()
p2 = Person()

# %%
print(p1.name, p2.name)

# %%
p1.name = 'hong'
p2.name = 'kim'

p1.gender = 'F'
p2.gender = 'M'

p1.age = 20
p2.age = 30

p1.height = 170
p2.height = 180

# %%
p1.greeting()
# Out:
# 안녕하세요. 나는 hong입니다.

# %%
p2.greeting()
# Out:
# 안녕하세요. 나는 kim입니다.

# %%
Person.greeting(p1)
# Out:
# 안녕하세요. 나는 hong입니다.

# %% [markdown]
# ## 생성자, 소멸자
#
# ```python
# class MyClass():
#
#     def __init__(self):
#         pass
#
#     def __del__(self):
#         pass

# %%
class Person():
    name = ''


    def __init__(self, n):  #생성자
        self.name = n
        print('생성됨')

    def __del__(self):  #소멸자
        print('소멸됨')

# %%
p1 = Person('kim') # => Person. __init__(p1, kim)를 실행하려고 한 것
p2 = Person('park')
# Out:
# 생성됨
# 소멸됨
# 생성됨
# 소멸됨

# %%
del p1
# Out:
# 소멸됨

# %%
del p2
# Out:
# 소멸됨

# %%
class Circle():
    pi = 3.14

    
    def __init__(self, r, x=0, y=0):
        self.r = r
        self.x = x
        self.y = y

    def info(self):
        print(f'반지름: {self.r}, 중심점: {self.x}, {self.y} ')

    def area(self):
        return self.r ** 2 * self.pi 

    def round(self):
        return self.r * self.pi * 2

    def move(self, x, y):
        self.x = x
        self.y = y

# %%
c1 = Circle(5)
c2 = Circle(3, 1, 1)

# %%
c1.info()
c2.info()
# Out:
# 반지름: 5, 중심점: 0, 0
# 반지름: 3, 중심점: 1, 1

# %%
print(c1.area())
print(c2.area())
# Out:
# 78.5
# 28.26

# %%
c1.round()
# Out:
# 31.400000000000002

# %%
c1.move(100, 100)
c1.info()
# Out:
# 반지름: 5, 중심점: 100, 100

# %%
class Point():
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def info(self):
        print(f'{self.x}, {self.y}')

# %%
p1 = Point(1, 1)
p2 = Point(2, 3)

# %%
class Circle():
    def __init__(self, r, point):
        self.r = r
        self.point = point

    def info(self):
        point = self.point
        x = point.x
        y = point.y
        print(f'반지름: {self.r} 중심점: {x}, {y}')

# %%
c1 = Circle(10, p1)
c2 = Circle(5, p2)
# Out:
# 소멸됨
# 소멸됨

# %%
c1.info()
# Out:
# 반지름: 10 중심점: 1, 1
